# %%
print((lambda a:a+a )(10))
# Out:
# 20

# %%
import pandas as pd

# %%
df=pd.DataFrame({
    'id':[1,2,3,4,5],
    'name':['Jeremy','Frank','Janet','Ryan','Mary'],
    'age':[20,25,15,10,30],
    'income':[4000,7000,200,0,10000]
})

# %%
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   20    4000
# 1   2   Frank   25    7000
# 2   3   Janet   15     200
# 3   4    Ryan   10       0
# 4   5    Mary   30   10000

# %%
df['age']=df.apply(lambda x:x['age']+3 ,axis=1)

# %%
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   23    4000
# 1   2   Frank   28    7000
# 2   3   Janet   18     200
# 3   4    Ryan   13       0
# 4   5    Mary   33   10000

# %%
df['age'] = df['age'].apply(lambda x:x+1) # appling lambda with pd

# %%
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   24    4000
# 1   2   Frank   29    7000
# 2   3   Janet   19     200
# 3   4    Ryan   14       0
# 4   5    Mary   34   10000

# %%
df['income']
# Out:
# 0     4000
# 1     7000
# 2      200
# 3        0
# 4    10000
# Name: income, dtype: int64

# %%
df['income']=list(map(lambda x: int(x+x*0.2),df['income'])) # lambda with map

# %%
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   24    4800
# 1   2   Frank   29    8400
# 2   3   Janet   19     240
# 3   4    Ryan   14       0
# 4   5    Mary   34   12000

# %%
# lambda with reduce

# %%
from functools import reduce

# %%
reduce(lambda x,y : x+y,df['income'])
# Out:
# 25440

# %%
import functools

# %%
functools.reduce(lambda x,y: x+y,df['income'])
# Out:
# 25440

# %%
df['category'] = df.apply(lambda x:'Adult' if x['age']>18 else 'Minor' ,axis=1)  # putting conditions for lambda

# %%
df
# Out:
#    id    name  age  income category
# 0   1  Jeremy   20    4800    Adult
# 1   2   Frank   25    8400    Adult
# 2   3   Janet   15     240    Minor
# 3   4    Ryan   10       0    Minor
# 4   5    Mary   30   12000    Adult

# %%
df['name'] = df.apply(lambda x: 'Pavan' if x['name']=='Ryan' else x['name'],axis=1)

# %%
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   20    4000
# 1   2   Frank   25    7000
# 2   3   Janet   15     200
# 3   4   Pavan   10       0
# 4   5    Mary   30   10000

# %%
df = pd.read_csv('Datasets/IMDB.csv')

# %%
df
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
df['AvgRating'] = (df['Rating'] + df['Metascore']/10)/2

# %%
df
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
def new_rating(genre,rating):
    if ('Thriller' in genre):
        return (min(10,rating+1))
    elif ('Comedy' in genre):
        return (max(0,rating-1))
    else:
        return (rating)

# %%
df['new_rating'] = df.apply(lambda x: new_rating(x['Genre'],x['Rating']),axis =1)

# %%
df
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
OR_df = df[ (df['Rating']>8.0) | (df['Votes']>9999999)]

# %%
OR_df
# Out:
#      Rank                                         Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 16     17                                 Hacksaw Ridge
# 18     19                                          Lion
# 26     27                       Bahubali: The Beginning
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 64     65                                  The Prestige
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# ...

# %%
four_df = df[ df.apply(lambda x: len(x['Title'].split(" "))>=4,axis=1)]  # TODO:

# %%
four_df
# Out:
#      Rank                                          Title  \
# 0       1                        Guardians of the Galaxy
# 8       9                             The Lost City of Z
# 10     11        Fantastic Beasts and Where to Find Them
# 15     16                        The Secret Life of Pets
# 21     22                          Manchester by the Sea
# 34     35               Resident Evil: The Final Chapter
# 35     36                     Captain America: Civil War
# 42     43                        Don't Fuck in the Woods
# 45     46    Pirates of the Caribbean: On Stranger Tides
# 50     51     Star Wars: Episode VII - The Force Awakens
# 60     61             Batman v Superman: Dawn of Justice
# 61     62                        The Autopsy of Jane Doe
# 62     63                          The Girl on the Train
# 63     64                           Fifty Shades of Grey
# 65     66                   Kingsman: The Secret Service
# ...

# %%
year_revenue_dict = df.groupby(['Year']).agg({'Revenue (Millions)':np.mean}).to_dict()['Revenue (Millions)']

# %%
def bool_provider(revenue, year):
    return revenue<year_revenue_dict[year]

# %%
new_df = df[df.apply(lambda x : bool_provider(x['Revenue (Millions)'],x['Year']),axis=1)]

# %%
new_df
# Out:
#      Rank                             Title                       Genre  \
# 5       6                    The Great Wall    Action,Adventure,Fantasy
# 8       9                The Lost City of Z  Action,Adventure,Biography
# 14     15                          Colossal         Action,Comedy,Drama
# 18     19                              Lion             Biography,Drama
# 20     21                              Gold    Adventure,Drama,Thriller
# 21     22             Manchester by the Sea                       Drama
# 26     27           Bahubali: The Beginning      Action,Adventure,Drama
# 27     28                        Dead Awake             Horror,Thriller
# 29     30                  Assassin's Creed      Action,Adventure,Drama
# 31     32                 Nocturnal Animals              Drama,Thriller
# 34     35  Resident Evil: The Final Chapter        Action,Horror,Sci-Fi
# 41     42                         Moonlight                       Drama
# ...

# %%
lambda x, y: x + y
# Out:
# <function __main__.<lambda>(x, y)>

# %%
_(1, 2         # last expression is used
# Out:
# 3

# %%
 high_ord_func = lambda x, func: x + func(x)  # using lambda as functions

# %%
high_ord_func(2,lambda x:x+2)
# Out:
# 6

# %%
high_ord_func(2,lambda x:x**3)
# Out:
# 10

# %%
high_ord_func(3,lambda x:x)
# Out:
# 6

# %%
# speed comparision lambda vs normal functions

# %%
import dis

# %%
add = lambda x,y: x+y

# %%
type(add)
# Out:
# function

# %%
dis.dis(add)
# Out:
#   1           0 LOAD_FAST                0 (x)
#               2 LOAD_FAST                1 (y)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
add           # function name is lambda
# Out:
# <function __main__.<lambda>(x, y)>

# %%
def add(x,y):
    return (x+y)

# %%
dis.dis(add)
# Out:
#   2           0 LOAD_FAST                0 (x)
#               2 LOAD_FAST                1 (y)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
add                             # function name is lambda
# Out:
# <function __main__.add(x, y)>

# %%
(lambda x: x%2 and 'odd' or 'even')(3)
# Out:
# 'odd'

# %%
(lambda x: 'even' if x%2==0 else 'odd')(3)
# Out:
# 'odd'
